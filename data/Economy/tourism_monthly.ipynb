# %% [markdown]
# ### Importing Required Libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Retrieving Data

# %%
dataset_id = "d_7e7b2ee60c6ffc962f80fef129cf306e"
url = "https://data.gov.sg/api/action/datastore_search?resource_id="  + dataset_id 
        
response = requests.get(url)
print(response.json())
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search', 'success': True, 'result': {'resource_id': 'd_7e7b2ee60c6ffc962f80fef129cf306e', 'fields': [{'type': 'text', 'id': 'DataSeries'}, {'type': 'numeric', 'id': '2024Nov'}, {'type': 'numeric', 'id': '2024Oct'}, {'type': 'numeric', 'id': '2024Sep'}, {'type': 'numeric', 'id': '2024Aug'}, {'type': 'numeric', 'id': '2024Jul'}, {'type': 'numeric', 'id': '2024Jun'}, {'type': 'numeric', 'id': '2024May'}, {'type': 'numeric', 'id': '2024Apr'}, {'type': 'numeric', 'id': '2024Mar'}, {'type': 'numeric', 'id': '2024Feb'}, {'type': 'numeric', 'id': '2024Jan'}, {'type': 'numeric', 'id': '2023Dec'}, {'type': 'numeric', 'id': '2023Nov'}, {'type': 'numeric', 'id': '2023Oct'}, {'type': 'numeric', 'id': '2023Sep'}, {'type': 'numeric', 'id': '2023Aug'}, {'type': 'numeric', 'id': '2023Jul'}, {'type': 'numeric', 'id': '2023Jun'}, {'type': 'numeric', 'id': '2023May'}, {'type': 'numeric', 'id': '2023Apr'}, {'type': 'numeric', 'id': '2023Mar'}, {'type': 'numeric', 'id': '2023Feb'}, {'type': 'numeric', 'id': '2023Jan'}, {'type': 'numeric', 'id': '2022Dec'}, {'type': 'numeric', 'id': '2022Nov'}, {'type': 'numeric', 'id': '2022Oct'}, {'type': 'numeric', 'id': '2022Sep'}, {'type': 'numeric', 'id': '2022Aug'}, {'type': 'numeric', 'id': '2022Jul'}, {'type': 'numeric', 'id': '2022Jun'}, {'type': 'numeric', 'id': '2022May'}, {'type': 'numeric', 'id': '2022Apr'}, {'type': 'numeric', 'id': '2022Mar'}, {'type': 'numeric', 'id': '2022Feb'}, {'type': 'numeric', 'id': '2022Jan'}, {'type': 'numeric', 'id': '2021Dec'}, {'type': 'numeric', 'id': '2021Nov'}, {'type': 'numeric', 'id': '2021Oct'}, {'type': 'numeric', 'id': '2021Sep'}, {'type': 'numeric', 'id': '2021Aug'}, {'type': 'numeric', 'id': '2021Jul'}, {'type': 'numeric', 'id': '2021Jun'}, {'type': 'numeric', 'id': '2021May'}, {'type': 'numeric', 'id': '2021Apr'}, {'type': 'numeric', 'id': '2021Mar'}, {'type': 'numeric', 'id': '2021Feb'}, {'type': 'numeric', 'id': '2021Jan'}, {'type': 'numeric', 'id': '2020Dec'}, {'type': 'numeric', 'id': '2020Nov'}, {'type': 'numeric', 'id': '2020Oct'}, {'type': 'numeric', 'id': '2020Sep'}, {'type': 'numeric', 'id': '2020Aug'}, {'type': 'numeric', 'id': '2020Jul'}, {'type': 'numeric', 'id': '2020Jun'}, {'type': 'numeric', 'id': '2020May'}, {'type': 'numeric', 'id': '2020Apr'}, {'type': 'numeric', 'id': '2020Mar'}, {'type': 'numeric', 'id': '2020Feb'}, {'type': 'numeric', 'id': '2020Jan'}, {'type': 'numeric', 'id': '2019Dec'}, {'type': 'numeric', 'id': '2019Nov'}, {'type': 'numeric', 'id': '2019Oct'}, {'type': 'numeric', 'id': '2019Sep'}, {'type': 'numeric', 'id': '2019Aug'}, {'type': 'numeric', 'id': '2019Jul'}, {'type': 'numeric', 'id': '2019Jun'}, {'type': 'numeric', 'id': '2019May'}, {'type': 'numeric', 'id': '2019Apr'}, {'type': 'numeric', 'id': '2019Mar'}, {'type': 'numeric', 'id': '2019Feb'}, {'type': 'numeric', 'id': '2019Jan'}, {'type': 'numeric', 'id': '2018Dec'}, {'type': 'numeric', 'id': '2018Nov'}, {'type': 'numeric', 'id': '2018Oct'}, {'type': 'numeric', 'id': '2018Sep'}, {'type': 'numeric', 'id': '2018Aug'}, {'type': 'numeric', 'id': '2018Jul'}, {'type': 'numeric', 'id': '2018Jun'}, {'type': 'numeric', 'id': '2018May'}, {'type': 'numeric', 'id': '2018Apr'}, {'type': 'numeric', 'id': '2018Mar'}, {'type': 'numeric', 'id': '2018Feb'}, {'type': 'numeric', 'id': '2018Jan'}, {'type': 'numeric', 'id': '2017Dec'}, {'type': 'numeric', 'id': '2017Nov'}, {'type': 'numeric', 'id': '2017Oct'}, {'type': 'numeric', 'id': '2017Sep'}, {'type': 'numeric', 'id': '2017Aug'}, {'type': 'numeric', 'id': '2017Jul'}, {'type': 'numeric', 'id': '2017Jun'}, {'type': 'numeric', 'id': '2017May'}, {'type': 'numeric', 'id': '2017Apr'}, {'type': 'numeric', 'id': '2017Mar'}, {'type': 'numeric', 'id': '2017Feb'}, {'type': 'numeric', 'id': '2017Jan'}, {'type': 'numeric', 'id': '2016Dec'}, {'type': 'numeric', 'id': '2016Nov'}, {'type': 'numeric', 'id': '2016Oct'}, {'type': 'numeric', 'id': '2016Sep'}, {'type': 'numeric', 'id': '2016 ...

# %% [markdown]
# ### Converting Data from ```.json``` to Pandas Dataframe

# %%
df = pd.DataFrame(response.json()['result']['records'])
print(df.shape)
display(df.head())
# Out:
# (62, 565)
#    _id                                         DataSeries  2024Nov  2024Oct  \
# 0    1  Total International Visitor Arrivals By Inboun...  1234673  1314484
# 1    2                                     Southeast Asia   437864   444033
# 2    3                                  Brunei Darussalam     4500     3959
# 3    4                                          Indonesia   194441   183714
# 4    5                                           Malaysia   101918   103432
#
#    2024Sep  2024Aug  2024Jul  2024Jun  2024May  2024Apr  ... 1978Oct 1978Sep  \
# 0  1269804  1539826  1602596  1250293  1277160  1343319  ...  177639  167980
# 1   417165   398576   475242   450962   431069   506437  ...   71707   75304
# 2     3968     5679     4401     3711     3857     4844  ...      na      na
# 3   173551   163910   209823   200085   189182   243892  ...      na      na
# 4   112110    79895    83067    83558    95621   106186  ...      na      na
#
#   1978Aug 1978Jul 1978Jun 1978May 1978Apr 1978Mar 1978Feb 1978Jan
# 0  201355  175968  149896  162667  162400  163199  147954  167016
# 1   82899   73672   67746   68036   73782   63299   57650   64500
# 2      na      na      na      na      na      na      na      na
# 3      na      na      na      na      na      na      na      na
# 4      na      na      na      na      na      na      na      na
#
# [5 rows x 565 columns]

# %% [markdown]
# ### Converting to ```.csv``` file

# %%
df.to_csv('Data/tourism_monthly.csv', index=False)
