# %% [markdown]
# ### Importing Required Libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Retrieving Data and Converting to Pandas Dataframe

# %%
dataset_id = "d_8b007d0a630351e2375d5d574e108058"
url = "https://data.gov.sg/api/action/datastore_search?resource_id="  + dataset_id 
        
response = requests.get(url)
json = response.json()
print(response.json())
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search', 'success': True, 'result': {'resource_id': 'd_8b007d0a630351e2375d5d574e108058', 'fields': [{'type': 'text', 'id': 'DataSeries'}, {'type': 'numeric', 'id': '2024'}, {'type': 'numeric', 'id': '2023'}, {'type': 'numeric', 'id': '2022'}, {'type': 'numeric', 'id': '2021'}, {'type': 'numeric', 'id': '2020'}, {'type': 'text', 'id': '2019'}, {'type': 'text', 'id': '2018'}, {'type': 'text', 'id': '2017'}, {'type': 'text', 'id': '2016'}, {'type': 'text', 'id': '2015'}, {'type': 'text', 'id': '2014'}, {'type': 'text', 'id': '2013'}, {'type': 'text', 'id': '2012'}, {'type': 'text', 'id': '2011'}, {'type': 'text', 'id': '2010'}, {'type': 'text', 'id': '2009'}, {'type': 'text', 'id': '2008'}, {'type': 'text', 'id': '2007'}, {'type': 'text', 'id': '2006'}, {'type': 'text', 'id': '2005'}, {'type': 'text', 'id': '2004'}, {'type': 'text', 'id': '2003'}, {'type': 'text', 'id': '2002'}, {'type': 'text', 'id': '2001'}, {'type': 'text', 'id': '2000'}, {'type': 'text', 'id': '1999'}, {'type': 'text', 'id': '1998'}, {'type': 'text', 'id': '1997'}, {'type': 'text', 'id': '1996'}, {'type': 'text', 'id': '1995'}, {'type': 'text', 'id': '1994'}, {'type': 'text', 'id': '1993'}, {'type': 'text', 'id': '1992'}, {'type': 'text', 'id': '1991'}, {'type': 'text', 'id': '1990'}, {'type': 'text', 'id': '1989'}, {'type': 'text', 'id': '1988'}, {'type': 'text', 'id': '1987'}, {'type': 'text', 'id': '1986'}, {'type': 'text', 'id': '1985'}, {'type': 'text', 'id': '1984'}, {'type': 'text', 'id': '1983'}, {'type': 'text', 'id': '1982'}, {'type': 'text', 'id': '1981'}, {'type': 'text', 'id': '1980'}, {'type': 'text', 'id': '1979'}, {'type': 'text', 'id': '1978'}, {'type': 'text', 'id': '1977'}, {'type': 'text', 'id': '1976'}, {'type': 'text', 'id': '1975'}, {'type': 'text', 'id': '1974'}, {'type': 'text', 'id': '1973'}, {'type': 'text', 'id': '1972'}, {'type': 'text', 'id': '1971'}, {'type': 'text', 'id': '1970'}, {'type': 'text', 'id': '1969'}, {'type': 'text', 'id': '1968'}, {'type': 'text', 'id': '1967'}, {'type': 'text', 'id': '1966'}, {'type': 'text', 'id': '1965'}, {'type': 'text', 'id': '1964'}, {'type': 'text', 'id': '1963'}, {'type': 'text', 'id': '1962'}, {'type': 'int4', 'id': '_id'}], 'records': [{'1962': '0.5', '1963': '2.1', '1964': '1.7', '1965': '0.3', '1966': '2', '1967': '3.3', '1968': '0.7', '1969': '-0.3', '1970': '0.3', '1971': '1.9', '1972': '2.1', '1973': '19.6', '1974': '22.4', '1975': '2.6', '1976': '-1.9', '1977': '3.2', '1978': '4.1', '1979': '4', '1980': '8.5', '1981': '8.2', '1982': '3.9', '1983': '1', '1984': '2.6', '1985': '0.5', '1986': '-1.4', '1987': '0.5', '1988': '1.5', '1989': '2.3', '1990': '3.5', '1991': '3.4', '1992': '2.2', '1993': '2.3', '1994': '3.1', '1995': '1.7', '1996': '1.4', '1997': '2', '1998': '-0.3', '1999': '0', '2000': '1.3', '2001': '1', '2002': '-0.4', '2003': '0.5', '2004': '1.7', '2005': '0.5', '2006': '1', '2007': '2.1', '2008': '6.6', '2009': '0.6', '2010': '2.8', '2011': '5.2', '2012': '4.6', '2013': '2.4', '2014': '1', '2015': '-0.5', '2016': '-0.5', '2017': '0.6', '2018': '0.4', '2019': '0.6', '2020': '-0.2', '2021': '2.3', '2022': '6.1', '2023': '4.8', '2024': '2.4', '_id': 1, 'DataSeries': 'All Items'}, {'1962': '0.7', '1963': '3.7', '1964': '2.5', '1965': '-0.5', '1966': '2.8', '1967': '4.7', '1968': '0.2', '1969': '-1.9', '1970': '-0.5', '1971': '2.3', '1972': '2.5', '1973': '33.8', '1974': '25.6', '1975': '1.1', '1976': '-6.2', '1977': '5', '1978': '5.7', '1979': '2.5', '1980': '8.5', '1981': '9.8', '1982': '4.9', '1983': '0.2', '1984': '1.5', '1985': '-1.2', '1986': '-1.5', '1987': '-0.2', '1988': '1.4', '1989': '1.1', '1990': '0.8', '1991': '1.6', '1992': '1.2', '1993': '1', '1994': '3.5', '1995': '2.3', '1996': '2.1', '1997': '2', '1998': '0.2', '1999': '0.9', '2000': '0.5', '2001': '0.5', '2002': '0', '2003': '0.6', '2004': '2', '2005': '1.3', '2006': '1.5', '2007': '3', '2008': '7.7', '2009': '2.3', '2010': '1.4', '2011': ...

# %%
df = pd.DataFrame(response.json()['result']['records'])
print(df.shape)
display(df.head())
# Out:
# (100, 65)
#   1962 1963 1964  1965 1966 1967 1968  1969  1970 1971  ...  2017 2018 2019  \
# 0  0.5  2.1  1.7   0.3    2  3.3  0.7  -0.3   0.3  1.9  ...   0.6  0.4  0.6
# 1  0.7  3.7  2.5  -0.5  2.8  4.7  0.2  -1.9  -0.5  2.3  ...   1.4  1.4  1.5
# 2   na   na   na    na   na   na   na    na    na   na  ...   1.3  1.3  1.1
# 3   na   na   na    na   na   na   na    na    na   na  ...   0.6  1.4  1.5
# 4   na   na   na    na   na   na   na    na    na   na  ...  -0.5  1.4  3.9
#
#    2020  2021  2022 2023 2024 _id                           DataSeries
# 0  -0.2   2.3   6.1  4.8  2.4   1                            All Items
# 1   1.9   1.4   5.3  5.8  2.8   2                                 Food
# 2   2.9   1.6   5.3  5.1  1.2   3      Food Excl Food Serving Services
# 3   1.9   0.6     4  6.8  3.6   4                      Bread & Cereals
# 4   1.8  -1.9  -1.4    3  2.2   5                                 Rice
#
# [5 rows x 65 columns]

# %%
while 'next' in json['result']['_links'] and json['result']['_links']['next']:
    curr_num = df.shape[0]
    response = requests.get("https://data.gov.sg" + json['result']['_links']['next'])
    json = response.json()
    df = pd.concat([df, pd.DataFrame(json['result']['records'])], ignore_index=True)
    print(f"Current number of records fetched: {df.shape[0]}")
    if df.shape[0] == curr_num:
        break


print(f"Total records fetched: {df.shape[0]}")
# Out:
# Current number of records fetched: 152
# Current number of records fetched: 152
# Total records fetched: 152

# %%
display(df)
# Out:
#     1962 1963 1964  1965 1966 1967 1968  1969  1970 1971  ...  2017  2018  \
# 0    0.5  2.1  1.7   0.3    2  3.3  0.7  -0.3   0.3  1.9  ...   0.6   0.4
# 1    0.7  3.7  2.5  -0.5  2.8  4.7  0.2  -1.9  -0.5  2.3  ...   1.4   1.4
# 2     na   na   na    na   na   na   na    na    na   na  ...   1.3   1.3
# 3     na   na   na    na   na   na   na    na    na   na  ...   0.6   1.4
# 4     na   na   na    na   na   na   na    na    na   na  ...  -0.5   1.4
# ..   ...  ...  ...   ...  ...  ...  ...   ...   ...  ...  ...   ...   ...
# 147   na   na   na    na   na   na   na    na    na   na  ...   2.9  -0.3
# 148   na   na   na    na   na   na   na    na    na   na  ...   0.1   1.8
# 149   na   na   na    na   na   na   na    na    na   na  ...   2.1     0
# 150   na   na   na    na   na   na   na    na    na   na  ...   1.7   1.3
# 151   na   na   na    na   na   na   na    na    na   na  ...   1.8   1.4
#
#      2019  2020  2021  2022  2023 2024  _id  \
# 0     0.6  -0.2   2.3   6.1   4.8  2.4    1
# 1     1.5   1.9   1.4   5.3   5.8  2.8    2
# 2     1.1   2.9   1.6   5.3   5.1  1.2    3
# 3     1.5   1.9   0.6     4   6.8  3.6    4
# 4     3.9   1.8  -1.9  -1.4     3  2.2    5
# ..    ...   ...   ...   ...   ...  ...  ...
# 147  -0.7  -6.9   3.2   2.8  -0.8    0  148
# 148   0.2  -2.9  -1.8  -0.4  -1.2  0.7  149
# 149  -0.1     0     0  -4.2  -0.6  1.4  150
# 150   0.9  -0.3   2.5   6.4   4.8  2.2  151
# 151   0.9  -0.3   2.5   6.6   4.9  2.2  152
#
#                                             DataSeries
# 0                                            All Items
# 1                                                 Food
# 2                      Food Excl Food Serving Services
# 3                                      Bread & Cereals
# 4                                                 Rice
# ..                                                 ...
# 147                             Other Personal Effects
# 148                                    Social Services
# 149                       Other Miscellaneous Services
# 150  All Items Less Imputed Rentals On Owner-Occupi...
# 151                       All Items Less Accommodation
#
# [152 rows x 65 columns]

# %% [markdown]
# ### Cleaning data

# %% [markdown]
# Only selecting certain years.

# %%
df = df.loc[:, ['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '_id', 'DataSeries']]

# %% [markdown]
# Rearraging columns.

# %%
df = df[['DataSeries', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']]
display(df.head())
# Out:
#                             DataSeries  2017 2018 2019  2020  2021  2022 2023  \
# 0                            All Items   0.6  0.4  0.6  -0.2   2.3   6.1  4.8
# 1                                 Food   1.4  1.4  1.5   1.9   1.4   5.3  5.8
# 2      Food Excl Food Serving Services   1.3  1.3  1.1   2.9   1.6   5.3  5.1
# 3                      Bread & Cereals   0.6  1.4  1.5   1.9   0.6     4  6.8
# 4                                 Rice  -0.5  1.4  3.9   1.8  -1.9  -1.4    3
#
#   2024
# 0  2.4
# 1  2.8
# 2  1.2
# 3  3.6
# 4  2.2

# %% [markdown]
# ### Converting to ```.csv``` file

# %%
df.to_csv("Data/cpi.csv", index=False)
